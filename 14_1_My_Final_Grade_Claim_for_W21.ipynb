# %% [markdown]
# ![Screenshot 2021-04-05 232248.png](data:image/png;base64,...)

# %% [markdown]
# ## Two Links of What I was Excited About

# %% [markdown]
# [BDD](https://colab.research.google.com/github/mloumeau/cse480-notebooks/blob/master/12_1_Ponder_and_Prove_Binary_Decision_Diagrams.ipynb#scrollTo=KYS-ZR9v6qTt)

# %% [markdown]
# [NP Completeness/SAT](https://colab.research.google.com/github/mloumeau/cse480-notebooks/blob/master/11_2_Ponder_and_Prove_NP_Completeness.ipynb#scrollTo=o8MUWcafhwnM)

# %% [markdown]
# ## Above and Beyond Instances

# %% [markdown]
# ### Learning to Learn
#
# This semester I've had the opportunity to work closer with Caleb than ever before, and am I ever grateful for that. Caleb has strengths in areas where I am weak, and I believe the same could be said about the reciprocal.  I know I've mentioned this numerous times, but all of the Discrete Math classes I've taken with you have pushed me further in team building than any other experience in my life.  This class has been no exception.
#
# [Sudoku Solver](https://colab.research.google.com/github/mloumeau/cse480-notebooks/blob/master/11_2_Ponder_and_Prove_NP_Completeness.ipynb#scrollTo=-dMVZAdWaI-F&line=2&uniqifier=1)
#
# In this instance, our whole team was stumped on how to decipher the constraints provided by the author of the solver.  We gave our best attempt and turned in our best work by the time it was due.  However, after a couple days of contemplation, I realized how the constraints worked. I went ahead and updated the file despite it being past due, just for the sake of a better understanding.  Once that was updated, I shared the concept with my team.  Caleb, being the eager learner that he is, was grateful and eventually repaid the favor.
#
# ![NFA of M'.png](data:image/png;base64,...)
#
# In the Ponder and Prove about PCP and mapping reductions, we found ourselves stumped once again. This time we fell victims to the concept of mapping reduction.  We gave the problem a couple hours of hour time before we had to concede. Caleb decided to look deeper into mapping reductions, despite the due date being behind us.  He found a way to understand it in terms that made sense to him, and proceeded to create a picture to help his team understand.  Above is said picture. I am grateful for his time to help us understand hard concepts.
#
# Overall, and once again, the difficulty of this course has allowed for us (not-social-unless-we-have-to-be people) to come together and learn something potentially greater than the material taught in this course.  I am excited and proud to say that he and I have taken full advantage of explaining concepts to one another out of the pure purpose of wanting to know more.

# %% [markdown]
# ## Digging Deeper
#
# After week 8's assignment of creating an elaborate Turing Machine, I wanted to show someone outside of my team the work we put into our creation, due to its complexity. I ended up showing my roommate, John, and he told me he's been exposed to Turing Machines in the past. He told me the story or Alan Turing and how the Turing Machine was created for purposes of war rather than convenience.  It was fascinating enough to have me want to learn more about Alan Turing so I spent the next day looking more into him.
#
# I loved seeing all the connections between Turing and Gödel, lambda calculus, Entscheidungsproblem, Alonzo Church, and multiple other topics covered in this class.
#
# Doing my own research on Turing allowed me to more fully understand the bigger idea of computational theory. Much like creating a WOK in DM1, the act of digging deeper allowed me see the connections between everything that has been taught in DM4 this semester.

# %% [markdown]
# ### Visit From Little Brother
#
# As previously discussed, I had my little brother visit me this past week. While his incentives were to come up here to experience Jackson Hole and Yellowstone, I did what I could to try to influence him to grow a stronger testimony.  In efforts to connect with him more fully, I asked him about what he's being doing with his time in his post-high school life.  He let me know that he's been very involved in work and investing his money. This led to talk about Bitcoin, and how to mine them.
#
# We watched a video together that explained the Bitcoin mining process. The video was marketed for a generic audience, but due to exposure of computational theory, my mind heard the video in a different light then how my brother's heard it.  Beyond the point of specialized hardware for mining, the problems that are to be solved in order to obtain a Bitcoin were made very obvious to me. This was a case of cracking NP-Complete problems.
#
# I spent the next 20 minutes explaining to my brother the concept of big O notation and how different algorithms have different levels of complexity. Naturally, this led to more discussion about NP-Completeness, as well as P vs NP.
#
# It was so fun having these theory-heavy concepts find a role in the practical world. Not only did this concept get me excited, but it allowed for me to more fully engage with my brother.
